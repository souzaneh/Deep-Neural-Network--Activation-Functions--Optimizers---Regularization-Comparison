# %% [markdown]
# #mount Google Drive

# %%
# conect to google drive
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

## Create a folder in the root directory
# !mkdir -p "/content/drive/My Drive/Folder_ch3_exe3"
# Out:
# Mounted at /content/drive

# %% [markdown]
# #  import libraries & load data

# %%
import tensorflow as tf
tf.config.run_functions_eagerly(True)

from tensorflow import keras
from keras import layers
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
tf.__version__
# Out:
# '2.18.0'

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()
x_train.shape,y_train.shape,  x_test.shape, y_test.shape
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# ((50000, 32, 32, 3), (50000, 1), (10000, 32, 32, 3), (10000, 1))

# %% [markdown]
# # data prepration

# %%
tf.data.experimental.enable_debug_mode()

# %%
# reshap/flatten data
X_train = x_train.reshape(-1, 3072)  # -1 ??
X_test_n = x_test.reshape(-1, 3072)
#X_test_n = X_test_flat
X_train.shape ,X_test_n.shape, y_train.shape
# Out:
# ((50000, 3072), (10000, 3072), (50000, 1))

# %%
from sklearn.model_selection import train_test_split

# %%
# train_test_split ---> val_size = 0.2

X_train_n, X_val_n, y_train_n, y_val_n =train_test_split(X_train ,y_train,test_size=0.2, random_state= 40,shuffle=True , stratify=None)

# %%
X_train_n.shape, X_val_n.shape , y_train_n.shape, y_val_n.shape #,x_test.shape, y_test.shape
# Out:
# ((40000, 3072), (10000, 3072), (40000, 1), (10000, 1))

# %%
# standardization
X_train_n,X_val_n,  X_test_n, = X_train_n /255,X_val_n/255 , X_test_n/255
#y_train_ohe = y_train_ohe.reshape(510000,)  # ????????????????????????????
X_train_n.shape ,#y_train_ohe. shape
# Out:
# ((40000, 3072),)

# %%
#### سوال
# در فرمت کنونی برای لایه آخر شبکه عصبی از چه لاس ای استفاده می‌کنید؟
## پاسخ  : SparseCategoricalCrossEntropy

# %%
#فرمت خروجی را به گونه‌ای تغییر دهید که بتوانیم برای لایه‌ی آخر از CategoricalCrossEntropy به عنوان Loss استفاده کنیم.
## convert target to OneHotEncoder
from sklearn.preprocessing import OneHotEncoder

ohe = OneHotEncoder()
y_train_ohe = ohe.fit_transform(y_train_n) .toarray()
y_val_ohe = ohe.fit_transform(y_val_n) .toarray()
y_test_ohe = ohe.fit_transform(y_test).toarray()
y_train_ohe.shape,y_test_ohe.shape
# Out:
# ((40000, 10), (10000, 10))

# %% [markdown]
# # Deep sequential model ---- activation : selu

# %%
# activation function : selu +  self_normalization
# define model

def create_model_selu():
    model = tf.keras.Sequential([
           keras.layers.Dense(units =50, kernel_initializer= keras.initializers.LecunNormal(seed=None), input_shape=(3072,)),
           keras.layers.Activation(activation='selu'),
           keras.layers.Dense(units= 100, activation='selu', kernel_initializer= keras.initializers.LecunNormal(seed=None) ),
           keras.layers.Dense(units= 10, activation='softmax')])
    model.compile(optimizer= 'sgd', loss= 'categorical_crossentropy',metrics= ['accuracy'])
    return model

# %%
#create model & callbacks
model= create_model_selu()
checkpoint_path_1 = "/content/drive/MyDrive/Folder_ch3_exe3/SL_modelchekpoint.keras"

SL_callbacks = [ #keras.callbacks.EarlyStopping(monitor = 'accuracy', patience = 5, restore_best_weights= True  ) ,
                 keras.callbacks.ModelCheckpoint(checkpoint_path_1,  monitor='val_loss', verbose = 0, mode ='auto', save_freq = 'epoch',
                                                 save_best_only = True )] #
# if interupt use the weights and continue training with adjusted  number of epochs
#model.load_weights(checkpoint_path_1)

# %%
#  train model
SL_model_history = model.fit(X_train_n, y_train_ohe, epochs=50, validation_data= (X_val_n,y_val_ohe),callbacks=SL_callbacks)
# Out:
# Epoch 1/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 47s 37ms/step - accuracy: 0.2541 - loss: 2.0805 - val_accuracy: 0.3672 - val_loss: 1.7824
# Epoch 2/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 49s 39ms/step - accuracy: 0.3677 - loss: 1.7757 - val_accuracy: 0.4037 - val_loss: 1.7032
# Epoch 3/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.3939 - loss: 1.7039 - val_accuracy: 0.4095 - val_loss: 1.6372
# Epoch 4/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 51s 41ms/step - accuracy: 0.4173 - loss: 1.6364 - val_accuracy: 0.4233 - val_loss: 1.6453
# Epoch 5/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 46s 37ms/step - accuracy: 0.4348 - loss: 1.5982 - val_accuracy: 0.4289 - val_loss: 1.6004
# Epoch 6/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 42s 34ms/step - accuracy: 0.4502 - loss: 1.5558 - val_accuracy: 0.4418 - val_loss: 1.5605
# Epoch 7/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 34ms/step - accuracy: 0.4554 - loss: 1.5286 - val_accuracy: 0.4462 - val_loss: 1.5624
# Epoch 8/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 42s 34ms/step - accuracy: 0.4655 - loss: 1.5067 - val_accuracy: 0.4640 - val_loss: 1.5272
# Epoch 9/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 42s 33ms/step - accuracy: 0.4717 - loss: 1.4859 - val_accuracy: 0.4485 - val_loss: 1.5403
# Epoch 10/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 42s 34ms/step - accuracy: 0.4795 - loss: 1.4670 - val_accuracy: 0.4512 - val_loss: 1.5491
# Epoch 11/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 34ms/step - accuracy: 0.4799 - loss: 1.4520 - val_accuracy: 0.4637 - val_loss: 1.5225
# Epoch 12/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 34ms/step - accuracy: 0.4878 - loss: 1.4325 - val_accuracy: 0.4484 - val_loss: 1.5441
# Epoch 13/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 35ms/step - accuracy: 0.4921 - loss: 1.4192 - val_accuracy: 0.4449 - val_loss: 1.5659
# Epoch 14/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 44s 35ms/step - accuracy: 0.4990 - loss: 1.4043 - val_accuracy: 0.4817 - val_loss: 1.4682
# Epoch 15/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 44s 35ms/step - accuracy: 0.5041 - loss: 1.3891 - val_accuracy: 0.4759 - val_loss: 1.4838
# Epoch 16/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 34ms/step - accuracy: 0.5067 - loss: 1.3834 - val_accuracy: 0.4729 - val_loss: 1.4863
# Epoch 17/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 35ms/step - accuracy: 0.5183 - loss: 1.3551 - val_accuracy: 0.4699 - val_loss: 1.4975
# Epoch 18/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 44s 35ms/step - accuracy: 0.5229 - loss: 1.3463 - val_accuracy: 0.4725 - val_loss: 1.4937
# Epoch 19/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 35ms/step - accuracy: 0.5211 - loss: 1.3445 - val_accuracy: 0.4704 - val_loss: 1.4693
# Epoch 20/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 35ms/step - accuracy: 0.5214 - loss: 1.3381 - val_accuracy: 0.4753 - val_loss: 1.4764
# Epoch 21/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 44s 35ms/step - accuracy: 0.5267 - loss: 1.3330 - val_accuracy: 0.4893 - val_loss: 1.4467
# Epoch 22/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 44s 36ms/step - accuracy: 0.5289 - loss: 1.3156 - val_accuracy: 0.4873 - val_loss: 1.4419
# Epoch 23/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 44s 35ms/step - accuracy: 0.5351 - loss: 1.3089 - val_accuracy: 0.4758 - val_loss: 1.5016
# Epoch 24/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 44s 35ms/step - accuracy: 0.5343 - loss: 1.2973 - val_accuracy: 0.4888 - val_loss: 1.4392
# Epoch 25/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 44s 35ms/step - accuracy: 0.5406 - loss: 1.3017 - val_accuracy: 0.4894 - val_loss: 1.4646
# Epoch 26/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 44s 35ms/step - accuracy: 0.5481 - loss: 1.2787 - val_accuracy: 0.4702 - val_loss: 1.5135
# Epoch 27/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 44s 35ms/step - accuracy: 0.5474 - loss: 1.2746 - val_accuracy: 0.4854 - val_loss: 1.4604
# Epoch 28/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 35ms/step - accuracy: 0.5488 - loss: 1.2632 - val_accuracy: 0.4888 - val_loss: 1.4540
# Epoch 29/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 35ms/step - accuracy: 0.5533 - loss: 1.2582 - val_accuracy: 0.4937 - val_loss: 1.4433
# Epoch 30/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 35ms/step - accuracy: 0.5593 - loss: 1.2391 - val_accuracy: 0.4837 - val_loss: 1.4659
# Epoch 31/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 44s 35ms/step - accuracy: 0.5607 - loss: 1.2354 - val_accuracy: 0.4948 - val_loss: 1.4297
# Epoch 32/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 35ms/step - accuracy: 0.5619 - loss: 1.2324 - val_accuracy: 0.4865 - val_loss: 1.4614
# Epoch 33/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - accuracy: 0.5632 - loss: 1.2279 - val_accuracy: 0.5006 - val_loss: 1.4197
# Epoch 34/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 44s 35ms/step - accuracy: 0.5675 - loss: 1.2124 - val_accuracy: 0.4843 - val_loss: 1.4760
# Epoch 35/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 35ms/step - accuracy: 0.5703 - loss: 1.2072 - val_accuracy: 0.4895 - val_loss: 1.4635
# Epoch 36/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 35ms/step - accuracy: 0.5702 - loss: 1.2056 - val_accuracy: 0.5059 - val_loss: 1.4200
# Epoch 37/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 35ms/step - accuracy: 0.5713 - loss: 1.2048 - val_accuracy: 0.4998 - val_loss: 1.4435
# Epoch 38/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 35ms/step - accuracy: 0.5842 - loss: 1.1777 - val_accuracy: 0.4984 - val_loss: 1.4542
# Epoch 39/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 35ms/step - accuracy: 0.5823 - loss: 1.1861 - val_accuracy: 0.4937 - val_loss: 1.4488
# Epoch 40/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 34ms/step - accuracy: 0.5789 - loss: 1.1772 - val_accuracy: 0.4988 - val_loss: 1.4513
# Epoch 41/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 35ms/step - accuracy: 0.5786 - loss: 1.1717 - val_accuracy: 0.4986 - val_loss: 1.4470
# Epoch 42/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 34ms/step - accuracy: 0.5837 - loss: 1.1626 - val_accuracy: 0.4980 - val_loss: 1.4550
# Epoch 43/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 34ms/step - accuracy: 0.5859 - loss: 1.1607 - val_accuracy: 0.5019 - val_loss: 1.4530
# Epoch 44/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 34ms/step - accuracy: 0.5907 - loss: 1.1526 - val_accuracy: 0.5000 - val_loss: 1.4662
# Epoch 45/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 35ms/step - accuracy: 0.5889 - loss: 1.1533 - val_accuracy: 0.4950 - val_loss: 1.4573
# Epoch 46/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 35ms/step - accuracy: 0.5916 - loss: 1.1424 - val_accuracy: 0.5046 - val_loss: 1.4423
# Epoch 47/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 35ms/step - accuracy: 0.5986 - loss: 1.1377 - val_accuracy: 0.5069 - val_loss: 1.4253
# Epoch 48/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 35ms/step - accuracy: 0.5947 - loss: 1.1433 - val_accuracy: 0.5084 - val_loss: 1.4210
# Epoch 49/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 34ms/step - accuracy: 0.6054 - loss: 1.1134 - val_accuracy: 0.4998 - val_loss: 1.4613
# Epoch 50/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 44s 35ms/step - accuracy: 0.5957 - loss: 1.1342 - val_accuracy: 0.4912 - val_loss: 1.5019

# %%
# save model & history

model_path= "/content/drive/My Drive/Folder_ch3_exe3/SL_model.keras"
model.save(model_path)

import pickle
#  path for save the pickle file
pickle_path = "/content/drive/My Drive/Folder_ch3_exe3/SL_model_history.pkl"
# Save the dictionary as a pickle file
with open(pickle_path, 'wb') as pickle_file:
    pickle.dump(SL_model_history.history, pickle_file)

# %%
fig, ax = plt.subplots(figsize=(12,5))
ax.plot(SL_model_history.history['loss'], label='loss')
ax.plot(SL_model_history.history['accuracy'], label='accuracy')
ax.plot(SL_model_history.history['val_loss'], label='val_loss')
ax.plot(SL_model_history.history['val_accuracy'], label='val_accuracy')
ax.legend()

# %%
# the first layer of model is used BachNormalization ---> the graph is smoother
fig, ax = plt.subplots(figsize=(12,5))
ax.plot(model_history.history['loss'], label='loss')
ax.plot(model_history.history['accuracy'], label='accuracy')
ax.plot(model_history.history['val_loss'], label='val_loss')
ax.plot(model_history.history['val_accuracy'], label='val_accuracy')
ax.legend()

# %% [markdown]
# # model : activation---> leaky relu

# %%
# define model  : activation---> leaky relu

def create_model_LR():
    model = tf.keras.Sequential([
           #keras.layers.BatchNormalization(),
           keras.layers.Dense(units =50,  input_shape=(3072,),kernel_initializer='he_normal'),
           keras.layers.LeakyReLU(alpha=0.3),
           keras.layers.BatchNormalization(),
           keras.layers.Dense(units= 100,kernel_initializer='he_normal'),
           keras.layers.LeakyReLU(alpha = 0.3),
           keras.layers.BatchNormalization(),
           keras.layers.Dense(units= 10, activation='softmax')])
    model.compile(optimizer= 'sgd', loss= 'categorical_crossentropy',metrics= ['accuracy'])
    return model

# %%
model_1= create_model_LR()
model_1_history = model_1.fit(X_train_n, y_train_ohe, epochs=50, validation_data= (X_val_n,y_val_ohe))
# Out:
# Epoch 1/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 65s 51ms/step - accuracy: 0.3247 - loss: 1.9372 - val_accuracy: 0.4007 - val_loss: 1.7292
# Epoch 2/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 84s 53ms/step - accuracy: 0.4131 - loss: 1.6732 - val_accuracy: 0.4048 - val_loss: 1.6834
# Epoch 3/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 70s 55ms/step - accuracy: 0.4385 - loss: 1.6111 - val_accuracy: 0.4156 - val_loss: 1.6401
# Epoch 4/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 65s 51ms/step - accuracy: 0.4525 - loss: 1.5660 - val_accuracy: 0.4342 - val_loss: 1.6077
# Epoch 5/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 65s 51ms/step - accuracy: 0.4692 - loss: 1.5202 - val_accuracy: 0.4003 - val_loss: 1.7026
# Epoch 6/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 65s 51ms/step - accuracy: 0.4752 - loss: 1.5053 - val_accuracy: 0.4453 - val_loss: 1.5745
# Epoch 7/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 84s 53ms/step - accuracy: 0.4814 - loss: 1.4759 - val_accuracy: 0.4204 - val_loss: 1.7014
# Epoch 8/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 65s 51ms/step - accuracy: 0.4893 - loss: 1.4542 - val_accuracy: 0.4220 - val_loss: 1.6821
# Epoch 9/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 70s 55ms/step - accuracy: 0.4960 - loss: 1.4326 - val_accuracy: 0.4724 - val_loss: 1.5105
# Epoch 10/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 81s 55ms/step - accuracy: 0.4998 - loss: 1.4197 - val_accuracy: 0.4290 - val_loss: 1.6269
# Epoch 11/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 77s 51ms/step - accuracy: 0.5054 - loss: 1.4067 - val_accuracy: 0.4593 - val_loss: 1.5407
# Epoch 12/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 87s 55ms/step - accuracy: 0.5090 - loss: 1.4039 - val_accuracy: 0.4582 - val_loss: 1.5430
# Epoch 13/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 66s 52ms/step - accuracy: 0.5112 - loss: 1.3842 - val_accuracy: 0.4518 - val_loss: 1.5475
# Epoch 14/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 70s 55ms/step - accuracy: 0.5186 - loss: 1.3671 - val_accuracy: 0.4462 - val_loss: 1.5745
# Epoch 15/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 78s 51ms/step - accuracy: 0.5262 - loss: 1.3612 - val_accuracy: 0.4359 - val_loss: 1.6262
# Epoch 16/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 86s 54ms/step - accuracy: 0.5249 - loss: 1.3546 - val_accuracy: 0.4257 - val_loss: 1.6298
# Epoch 17/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 65s 51ms/step - accuracy: 0.5289 - loss: 1.3368 - val_accuracy: 0.4633 - val_loss: 1.5198
# Epoch 18/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 65s 51ms/step - accuracy: 0.5351 - loss: 1.3278 - val_accuracy: 0.4789 - val_loss: 1.4868
# Epoch 19/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 88s 56ms/step - accuracy: 0.5321 - loss: 1.3242 - val_accuracy: 0.4698 - val_loss: 1.5204
# Epoch 20/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 81s 55ms/step - accuracy: 0.5383 - loss: 1.3133 - val_accuracy: 0.4912 - val_loss: 1.4664
# Epoch 21/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 65s 51ms/step - accuracy: 0.5409 - loss: 1.3013 - val_accuracy: 0.4700 - val_loss: 1.5341
# Epoch 22/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 87s 55ms/step - accuracy: 0.5457 - loss: 1.2916 - val_accuracy: 0.4809 - val_loss: 1.5084
# Epoch 23/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 78s 52ms/step - accuracy: 0.5401 - loss: 1.2911 - val_accuracy: 0.4688 - val_loss: 1.5046
# Epoch 24/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 82s 52ms/step - accuracy: 0.5535 - loss: 1.2681 - val_accuracy: 0.4868 - val_loss: 1.4849
# Epoch 25/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 85s 55ms/step - accuracy: 0.5538 - loss: 1.2770 - val_accuracy: 0.4739 - val_loss: 1.5310
# Epoch 26/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 79s 52ms/step - accuracy: 0.5576 - loss: 1.2559 - val_accuracy: 0.4423 - val_loss: 1.6544
# Epoch 27/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 81s 52ms/step - accuracy: 0.5514 - loss: 1.2678 - val_accuracy: 0.4496 - val_loss: 1.6019
# Epoch 28/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 67s 52ms/step - accuracy: 0.5623 - loss: 1.2403 - val_accuracy: 0.4793 - val_loss: 1.4860
# Epoch 29/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 71s 56ms/step - accuracy: 0.5613 - loss: 1.2373 - val_accuracy: 0.4686 - val_loss: 1.5724
# Epoch 30/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 70s 55ms/step - accuracy: 0.5668 - loss: 1.2328 - val_accuracy: 0.4804 - val_loss: 1.5151
# Epoch 31/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 83s 56ms/step - accuracy: 0.5632 - loss: 1.2385 - val_accuracy: 0.4370 - val_loss: 1.6534
# Epoch 32/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 76s 52ms/step - accuracy: 0.5690 - loss: 1.2247 - val_accuracy: 0.4712 - val_loss: 1.5168
# Epoch 33/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 70s 55ms/step - accuracy: 0.5685 - loss: 1.2252 - val_accuracy: 0.4636 - val_loss: 1.5937
# Epoch 34/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 84s 56ms/step - accuracy: 0.5744 - loss: 1.2099 - val_accuracy: 0.4728 - val_loss: 1.5530
# Epoch 35/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 77s 53ms/step - accuracy: 0.5722 - loss: 1.2224 - val_accuracy: 0.4745 - val_loss: 1.5637
# Epoch 36/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 81s 52ms/step - accuracy: 0.5779 - loss: 1.2056 - val_accuracy: 0.4829 - val_loss: 1.5173
# Epoch 37/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 87s 56ms/step - accuracy: 0.5796 - loss: 1.1943 - val_accuracy: 0.4631 - val_loss: 1.5557
# Epoch 38/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 77s 52ms/step - accuracy: 0.5747 - loss: 1.1956 - val_accuracy: 0.4799 - val_loss: 1.4995
# Epoch 39/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 82s 52ms/step - accuracy: 0.5873 - loss: 1.1726 - val_accuracy: 0.4893 - val_loss: 1.4857
# Epoch 40/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 83s 53ms/step - accuracy: 0.5817 - loss: 1.1781 - val_accuracy: 0.4917 - val_loss: 1.5025
# Epoch 41/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 85s 56ms/step - accuracy: 0.5829 - loss: 1.1781 - val_accuracy: 0.4882 - val_loss: 1.4968
# Epoch 42/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 67s 53ms/step - accuracy: 0.5865 - loss: 1.1687 - val_accuracy: 0.4736 - val_loss: 1.5384
# Epoch 43/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 85s 55ms/step - accuracy: 0.5850 - loss: 1.1687 - val_accuracy: 0.4513 - val_loss: 1.6416
# Epoch 44/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 78s 52ms/step - accuracy: 0.5919 - loss: 1.1586 - val_accuracy: 0.4940 - val_loss: 1.5179
# Epoch 45/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 87s 56ms/step - accuracy: 0.5980 - loss: 1.1484 - val_accuracy: 0.4878 - val_loss: 1.5177
# Epoch 46/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 77s 52ms/step - accuracy: 0.5929 - loss: 1.1482 - val_accuracy: 0.4718 - val_loss: 1.5380
# Epoch 47/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 67s 52ms/step - accuracy: 0.6008 - loss: 1.1369 - val_accuracy: 0.4577 - val_loss: 1.6587
# Epoch 48/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 82s 52ms/step - accuracy: 0.5985 - loss: 1.1461 - val_accuracy: 0.4848 - val_loss: 1.5244
# Epoch 49/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 82s 52ms/step - accuracy: 0.5964 - loss: 1.1386 - val_accuracy: 0.4534 - val_loss: 1.6505
# Epoch 50/50
# 1275/1275 ━━━━━━━━━━━━━━━━━━━━ 87s 56ms/step - accuracy: 0.5945 - loss: 1.1365 - val_accuracy: 0.4964 - val_loss: 1.4890

# %%
# save history
import pickle
# Specify the path where you want to save the pickle file
pickle_path_1 = "/content/drive/My Drive/My Folder8/model_1_history.pkl"

# Save the dictionary as a pickle file
with open(pickle_path_1, 'wb') as pickle_file:
    pickle.dump(model_1_history.history, pickle_file)

# %%
# Graph
fig, ax = plt.subplots(figsize=(12,5))
# selu activation
ax.plot(model_history.history['loss'], label='loss_SL')
ax.plot(model_history.history['accuracy'], label='accurac_SL')
ax.plot(model_history.history['val_loss'], label='val_los_SL')
ax.plot(model_history.history['val_accuracy'], label='val_accuracy_SL')
# leakyRelu activation
ax.plot(model_1_history.history['loss'], label='loss_LR',linestyle='dashed')
ax.plot(model_1_history.history['accuracy'], label='accuracy_LR',linestyle='dashed')
ax.plot(model_1_history.history['val_loss'], label='val_loss_LR',linestyle='dashed')
ax.plot(model_1_history.history['val_accuracy'], label='val_accuracy_LR',linestyle='dashed')
ax.legend()

# %% [markdown]
# # Transfer_learning

# %%
model_best= keras.models.load_model('/content/drive/MyDrive/Folder_ch3_exe3/SL_model.keras')
model_best.load_weights('/content/drive/MyDrive/Folder_ch3_exe3/SL_modelchekpoint.keras')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-6-323440641.py in <cell line: 0>()
# ----> 1 model_best= keras.models.load_model('/content/drive/MyDrive/Folder_ch3_exe3/SL_model.keras')
#       2 model_best.load_weights('/content/drive/MyDrive/Folder_ch3_exe3/SL_modelchekpoint.keras')
#
# NameError: name 'keras' is not defined

# %%
model_best.get_weights()[0]
# Out:
# array([[-0.03313119, -0.00678901, -0.04310467, ..., -0.02234354,
#          0.02595495, -0.04198036],
#        [-0.05769468,  0.02968961, -0.07446042, ..., -0.01059062,
#          0.04746962,  0.02196683],
#        [ 0.00234057, -0.00846143, -0.06762131, ..., -0.05578372,
#          0.01935529,  0.02846684],
#        ...,
#        [-0.04284767, -0.01272093,  0.02285207, ...,  0.01985887,
#          0.02459863, -0.00341578],
#        [-0.02767811, -0.0010355 , -0.00699935, ..., -0.04399301,
#         -0.01782579,  0.04009678],
#        [-0.02069557,  0.01390829,  0.01299765, ..., -0.06131982,
#          0.05698243,  0.00426312]], dtype=float32)

# %%
built_model = keras.models.Sequential(model_best.layers[:-1])
built_model.add(keras.layers.Dense(1,activation='sigmoid',name='new_layer'))
built_model.summary()
# Out:
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 50)                  │         153,650 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 50)                  │             200 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 50)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 100)                 │           5,100 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ new_layer (Dense)                    │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 158,950 (620.90 KB)
#  Trainable params: 158,850 (620.51 KB)
#  Non-trainable params: 100 (400.00 B)

# %%
# compile model
built_model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# predict y as horse=7 or not
y_train_hor = np.where(y_train==7,1,0)[:6000]
y_test_hor = np.where(y_test==7,1,0)[:1000]

X_train_hor6 = X_train_n[:6000,:]
X_test_hor6 = X_test_n[:1000,:]

y_train_hor.sum()
# Out:
# 597

# %%
for layers in built_model.layers[:-1]:
  layers.trainable = False
  print(layers.trainable)
# Out:
# True
# True
# True
# True

# %%
#fit model and get duration time with 4 frozen layers in built_model
import time
start_time = time.time()

built_mode1_history = built_model.fit(x=X_train_hor6,y=y_train_hor, epochs=10, validation_split=0.)#,callbacks=model1_callbacks)

end_time = time.time()
print(f"Total training time for 5  epochs _4frozen layers:   {end_time - start_time:.2f}   seconds.",end='\n')
loss,accuracy = built_model.evaluate(X_train_hor6,y_train_hor)
print(f"accuracy for 10 epochs  and 4 frozen layers in model is :   {accuracy}  . ",end='\n')
# Out:
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/structured_function.py:258: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.7521 - loss: 0.5706
# Epoch 2/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.8854 - loss: 0.3642
# Epoch 3/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - accuracy: 0.9038 - loss: 0.3367
# Epoch 4/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - accuracy: 0.8985 - loss: 0.3495
# Epoch 5/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.9019 - loss: 0.3334
# Epoch 6/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.8936 - loss: 0.3499
# Epoch 7/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - accuracy: 0.8990 - loss: 0.3346
# Epoch 8/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9115 - loss: 0.3085
# Epoch 9/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.8993 - loss: 0.3384
# Epoch 10/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9079 - loss: 0.3148
# Total training time for 5  epochs _4frozen layers:   73.30   seconds.
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9012 - loss: 0.3309
# accuracy for 10 epochs  and 4 frozen layers in model is :   0.9003333449363708  .

# %%
#fit model and get duration time with 4 trainable layers in built_model
import time
start_time = time.time()

built_mode1_history = built_model.fit(x=X_train_hor6,y=y_train_hor, epochs=10, validation_split=0.)#,callbacks=model1_callbacks)

end_time = time.time()
print(f"Total training time for 5  epochs _4frozen layers:   {end_time - start_time:.2f}   seconds.",end='\n')
loss,accuracy = built_model.evaluate(X_train_hor6,y_train_hor)
print(f"accuracy for 10 epochs  and 4 trainable layers in model is :   {accuracy}  . ",end='\n')
# Out:
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/structured_function.py:258: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - accuracy: 0.7579 - loss: 0.5403
# Epoch 2/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step - accuracy: 0.8968 - loss: 0.3511
# Epoch 3/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 43ms/step - accuracy: 0.8955 - loss: 0.3413
# Epoch 4/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 9s 36ms/step - accuracy: 0.9077 - loss: 0.3056
# Epoch 5/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.9039 - loss: 0.3099
# Epoch 6/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - accuracy: 0.8993 - loss: 0.3152
# Epoch 7/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 43ms/step - accuracy: 0.8917 - loss: 0.3242
# Epoch 8/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9018 - loss: 0.3014
# Epoch 9/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - accuracy: 0.8976 - loss: 0.3039
# Epoch 10/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.8988 - loss: 0.3018
# Total training time for 5  epochs _4frozen layers:   91.14   seconds.
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.9052 - loss: 0.3089
# accuracy for 10 epochs  and 4 trainable layers in model is :   0.903166651725769  .

# %%
# در اينجا مدل اوليه را در گوگل درايو ذخيره دارم و لذا از كلون كردن استفاده نكردم

# اين مدل كلون شده بدون تغيير حفظ مي شود و فقط يكبار اجرا كنم
#model0_cloned= keras.models.clone_model(model0)
#model0_cloned .set_weights(model0.get_weights())

#cloned_path= "/content/drive/My Drive/Folder_ch3_exe3/model0_cloned.keras"
#model0_cloned .save(cloned_path)

# %% [markdown]
# # optimizers

# %%
model = create_model_selu()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# loss and accuracy are saved in  : SL_model_history
import pickle
pickle_path = "/content/drive/My Drive/Folder_ch3_exe3/SL_model_history.pkl"

with open(pickle_path,'rb')as file:
     SL_model_history = pickle.load(file)

# %%
# define model:
def create_model_selu():
    model = tf.keras.Sequential([
           keras.layers.Dense(units =50, kernel_initializer= keras.initializers.LecunNormal(seed=None), input_shape=(3072,)),
         keras.layers.BatchNormalization(),
           keras.layers.Activation(activation='selu'),
           keras.layers.Dense(units= 100, activation='selu', kernel_initializer= keras.initializers.LecunNormal(seed=None) ),
           keras.layers.Dense(units= 10, activation='softmax')])
    opt = keras.optimizers.SGD(learning_rate=0.01,momentum=0.9,nesterov= True)
    model.compile(optimizer= opt, loss= 'categorical_crossentropy',metrics= ['accuracy'])
    return model

#create model & callbacks
model= create_model_selu()
checkpoint_path_1 = "/content/drive/MyDrive/Folder_ch3_exe3/SL_modelchekpoint.keras" # sgd
checkpoint_path_adam = "/content/drive/MyDrive/Folder_ch3_exe3/adam_modelchekpoint.keras"
checkpoint_path_nadam = "/content/drive/MyDrive/Folder_ch3_exe3/nadam_modelchekpoint.keras"
checkpoint_path_adagrad = "/content/drive/MyDrive/Folder_ch3_exe3/adagrad_modelchekpoint.keras"
checkpoint_path_sgdm = "/content/drive/MyDrive/Folder_ch3_exe3/sgdm_modelchekpoint.keras"
checkpoint_path_sgdmnv = "/content/drive/MyDrive/Folder_ch3_exe3/sgdmnv_modelchekpoint.keras"

callbacks = [keras.callbacks.ModelCheckpoint(checkpoint_path_sgdmnv,  monitor='val_loss', verbose = 0, mode ='auto', save_freq = 'epoch',
                                                 save_best_only = True )]
#  train model
sgdmnv_model_history = model.fit(X_train_n, y_train_ohe, epochs=50, validation_data= (X_val_n,y_val_ohe),callbacks=callbacks)

print('-------------training was finished------------')

# save  model & history
sgdmnv_model_path= "/content/drive/My Drive/Folder_ch3_exe3/sgdmnv_model.keras"
model.save(sgdmnv_model_path)

import pickle
#  path for save the pickle file
history_path_sgdmnv = "/content/drive/My Drive/Folder_ch3_exe3/sgdmnv_model_history.pkl"
# Save the dictionary as a pickle file
with open(history_path_sgdmnv, 'wb') as pickle_file:
    pickle.dump(sgdmnv_model_history.history, pickle_file)

print('----------------sgdmnv files were saved------------')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/structured_function.py:258: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# Epoch 1/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 61ms/step - accuracy: 0.3237 - loss: 1.8977 - val_accuracy: 0.3463 - val_loss: 1.8685
# Epoch 2/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 78s 58ms/step - accuracy: 0.4123 - loss: 1.6580 - val_accuracy: 0.3699 - val_loss: 1.8277
# Epoch 3/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 73s 59ms/step - accuracy: 0.4423 - loss: 1.5671 - val_accuracy: 0.3983 - val_loss: 1.7152
# Epoch 4/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 82s 59ms/step - accuracy: 0.4555 - loss: 1.5281 - val_accuracy: 0.4499 - val_loss: 1.5438
# Epoch 5/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 80s 57ms/step - accuracy: 0.4778 - loss: 1.4680 - val_accuracy: 0.4176 - val_loss: 1.6505
# Epoch 6/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 72s 58ms/step - accuracy: 0.4938 - loss: 1.4413 - val_accuracy: 0.4242 - val_loss: 1.6556
# Epoch 7/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 82s 58ms/step - accuracy: 0.4963 - loss: 1.4093 - val_accuracy: 0.4376 - val_loss: 1.6254
# Epoch 8/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 73s 58ms/step - accuracy: 0.5102 - loss: 1.3773 - val_accuracy: 0.4558 - val_loss: 1.5446
# Epoch 9/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 73s 58ms/step - accuracy: 0.5129 - loss: 1.3728 - val_accuracy: 0.4435 - val_loss: 1.6258
# Epoch 10/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 81s 58ms/step - accuracy: 0.5269 - loss: 1.3389 - val_accuracy: 0.4738 - val_loss: 1.5447
# Epoch 11/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 73s 59ms/step - accuracy: 0.5260 - loss: 1.3289 - val_accuracy: 0.4753 - val_loss: 1.5161
# Epoch 12/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 84s 60ms/step - accuracy: 0.5397 - loss: 1.2950 - val_accuracy: 0.4530 - val_loss: 1.6202
# Epoch 13/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 57ms/step - accuracy: 0.5388 - loss: 1.2901 - val_accuracy: 0.4371 - val_loss: 1.7108
# Epoch 14/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 83s 57ms/step - accuracy: 0.5403 - loss: 1.2910 - val_accuracy: 0.4423 - val_loss: 1.7027
# Epoch 15/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 82s 57ms/step - accuracy: 0.5495 - loss: 1.2624 - val_accuracy: 0.4616 - val_loss: 1.6205
# Epoch 16/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 82s 57ms/step - accuracy: 0.5527 - loss: 1.2519 - val_accuracy: 0.4449 - val_loss: 1.6867
# Epoch 17/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 82s 57ms/step - accuracy: 0.5516 - loss: 1.2532 - val_accuracy: 0.4390 - val_loss: 1.7322
# Epoch 18/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 72s 58ms/step - accuracy: 0.5622 - loss: 1.2392 - val_accuracy: 0.4627 - val_loss: 1.6228
# Epoch 19/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 82s 58ms/step - accuracy: 0.5579 - loss: 1.2301 - val_accuracy: 0.4805 - val_loss: 1.5150
# Epoch 20/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 81s 57ms/step - accuracy: 0.5715 - loss: 1.2030 - val_accuracy: 0.4743 - val_loss: 1.5854
# Epoch 21/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 72s 58ms/step - accuracy: 0.5748 - loss: 1.1981 - val_accuracy: 0.4518 - val_loss: 1.6789
# Epoch 22/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 82s 58ms/step - accuracy: 0.5787 - loss: 1.1772 - val_accuracy: 0.4479 - val_loss: 1.6773
# Epoch 23/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 80s 56ms/step - accuracy: 0.5814 - loss: 1.1821 - val_accuracy: 0.4235 - val_loss: 1.7528
# Epoch 24/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 85s 59ms/step - accuracy: 0.5803 - loss: 1.1812 - val_accuracy: 0.4324 - val_loss: 1.8297
# Epoch 25/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 81s 58ms/step - accuracy: 0.5848 - loss: 1.1598 - val_accuracy: 0.4248 - val_loss: 1.8042
# Epoch 26/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 72s 58ms/step - accuracy: 0.5887 - loss: 1.1541 - val_accuracy: 0.4485 - val_loss: 1.7082
# Epoch 27/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 81s 57ms/step - accuracy: 0.5827 - loss: 1.1563 - val_accuracy: 0.4595 - val_loss: 1.6656
# Epoch 28/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 83s 58ms/step - accuracy: 0.5929 - loss: 1.1347 - val_accuracy: 0.4494 - val_loss: 1.7494
# Epoch 29/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 84s 60ms/step - accuracy: 0.5874 - loss: 1.1462 - val_accuracy: 0.4648 - val_loss: 1.6456
# Epoch 30/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 84s 62ms/step - accuracy: 0.5925 - loss: 1.1308 - val_accuracy: 0.4277 - val_loss: 1.8728
# Epoch 31/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 76s 61ms/step - accuracy: 0.6010 - loss: 1.1102 - val_accuracy: 0.4693 - val_loss: 1.6449
# Epoch 32/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 73s 58ms/step - accuracy: 0.5999 - loss: 1.1176 - val_accuracy: 0.4383 - val_loss: 1.8087
# Epoch 33/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 75s 60ms/step - accuracy: 0.6084 - loss: 1.0935 - val_accuracy: 0.4769 - val_loss: 1.6517
# Epoch 34/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 76s 61ms/step - accuracy: 0.6098 - loss: 1.0945 - val_accuracy: 0.4624 - val_loss: 1.7104
# Epoch 35/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 72s 58ms/step - accuracy: 0.6078 - loss: 1.0961 - val_accuracy: 0.4783 - val_loss: 1.6266
# Epoch 36/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 72s 57ms/step - accuracy: 0.6159 - loss: 1.0811 - val_accuracy: 0.4764 - val_loss: 1.6332
# Epoch 37/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 73s 58ms/step - accuracy: 0.6153 - loss: 1.0753 - val_accuracy: 0.4669 - val_loss: 1.6915
# Epoch 38/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 72s 58ms/step - accuracy: 0.6147 - loss: 1.0773 - val_accuracy: 0.4679 - val_loss: 1.7288
# Epoch 39/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 81s 57ms/step - accuracy: 0.6144 - loss: 1.0612 - val_accuracy: 0.4394 - val_loss: 1.8318
# Epoch 40/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 75s 60ms/step - accuracy: 0.6176 - loss: 1.0678 - val_accuracy: 0.4414 - val_loss: 1.8127
# Epoch 41/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 82s 60ms/step - accuracy: 0.6181 - loss: 1.0639 - val_accuracy: 0.4655 - val_loss: 1.7479
# Epoch 42/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 79s 58ms/step - accuracy: 0.6214 - loss: 1.0533 - val_accuracy: 0.4628 - val_loss: 1.7385
# Epoch 43/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 82s 58ms/step - accuracy: 0.6235 - loss: 1.0475 - val_accuracy: 0.4259 - val_loss: 2.0022
# Epoch 44/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 88s 63ms/step - accuracy: 0.6298 - loss: 1.0364 - val_accuracy: 0.4352 - val_loss: 1.9889
# Epoch 45/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 72s 58ms/step - accuracy: 0.6337 - loss: 1.0226 - val_accuracy: 0.4526 - val_loss: 1.7559
# Epoch 46/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 85s 61ms/step - accuracy: 0.6336 - loss: 1.0270 - val_accuracy: 0.4271 - val_loss: 1.9555
# Epoch 47/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 74s 59ms/step - accuracy: 0.6362 - loss: 1.0107 - val_accuracy: 0.4355 - val_loss: 1.8780
# Epoch 48/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 81s 58ms/step - accuracy: 0.6348 - loss: 1.0175 - val_accuracy: 0.4675 - val_loss: 1.7417
# Epoch 49/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 74s 59ms/step - accuracy: 0.6381 - loss: 1.0112 - val_accuracy: 0.4546 - val_loss: 1.7568
# Epoch 50/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 81s 58ms/step - accuracy: 0.6422 - loss: 1.0008 - val_accuracy: 0.4590 - val_loss: 1.8449
# -------------training was finished------------
# ----------------sgdmnv files were saved------------

# %%
import pickle
history_path = "/content/drive/My Drive/Folder_ch3_exe3/SL_model_history.pkl"
# load the dictionary as a pickle file
with open(history_path, 'rb') as pickle_file:
 SL_model_history = pickle.load(pickle_file)

# %%
# loss and accuracy are saved in  : SL_model_history
import pickle
pickle_path =  "/content/drive/MyDrive/Folder_ch3_exe3/sgdmnv_model_history.pkl"#  "/content/drive/My Drive/Folder_ch3_exe3/SL_model_history.pkl"

with open(pickle_path,'rb')as file:
   sgdmnv_model_history = pickle.load(file)

# %%
nadam_model_history
adagrad_model_history
sgdm_model_history
sgdmnv_model_history
SL_model_history
adam_model_history
# Out:
# {'accuracy': [0.36970001459121704,
#   0.42719998955726624,
#   0.4516749978065491,
#   0.47200000286102295,
#   0.4854249954223633,
#   0.5006499886512756,
#   0.5115500092506409,
#   0.520924985408783,
#   0.5343999862670898,
#   0.5432000160217285,
#   0.54892498254776,
#   0.5559250116348267,
#   0.5608749985694885,
#   0.5656750202178955,
#   0.5725250244140625,
#   0.5769500136375427,
#   0.5817000269889832,
#   0.5862249732017517,
#   0.5902000069618225,
#   0.5940750241279602,
#   0.5983250141143799,
#   0.6023749709129333,
#   0.6084499955177307,
#   0.6105750203132629,
#   0.6156250238418579,
#   0.6147750020027161,
#   0.6217250227928162,
#   0.6242250204086304,
#   0.6267250180244446,
#   0.6301000118255615,
#   0.6315249800682068,
#   0.6359249949455261,
#   0.6368250250816345,
#   0.6420249938964844,
#   0.6438249945640564,
#   0.6456249952316284,
#   0.6509749889373779,
#   0.6507999897003174,
#   0.6528499722480774,
#   0.65767502784729,
#   0.6576499938964844,
#   0.6597999930381775,
#   0.6633250117301941,
#   0.6626999974250793,
#   0.6655499935150146,
#   0.670199990272522,
#   0.6687750220298767,
#   0.6717749834060669,
#   0.67392498254776,
#   0.6720499992370605],
#  'loss': [1.7848600149154663,
#   1.6185152530670166,
#   1.5482217073440552,
#   1.4943305253982544,
#   1.4508060216903687,
#   1.4076040983200073,
#   1.376621127128601,
#   1.3471248149871826,
#   1.31868314743042,
#   1.2957886457443237,
#   1.2699344158172607,
#   1.254510521888733,
#   1.2343204021453857,
#   1.2239058017730713,
#   1.2042313814163208,
#   1.190643310546875,
#   1.1725425720214844,
#   1.1607730388641357,
#   1.1509854793548584,
#   1.1354326009750366,
#   1.123550534248352,
#   1.1116670370101929,
#   1.1016342639923096,
#   1.094869613647461,
#   1.0798808336257935,
#   1.0715292692184448,
#   1.061540961265564,
#   1.0539835691452026,
#   1.0434229373931885,
#   1.033616065979004,
#   1.025620937347412,
#   1.0199257135391235,
#   1.0121973752975464,
#   1.0017927885055542,
#   0.9942744970321655,
#   0.9889049530029297,
#   0.9786575436592102,
#   0.9746069312095642,
#   0.9683461785316467,
#   0.9612749218940735,
#   0.9580078125,
#   0.9470476508140564,
#   0.9394940137863159,
#   0.9388418197631836,
#   0.9267827868461609,
#   0.9216669201850891,
#   0.920386791229248,
#   0.9127905368804932,
#   0.9050477743148804,
#   0.9070898294448853],
#  'val_accuracy': [0.37770000100135803,
#   0.39809998869895935,
#   0.4138000011444092,
#   0.415800005197525,
#   0.42170000076293945,
#   0.459199994802475,
#   0.43799999356269836,
#   0.4456000030040741,
#   0.45019999146461487,
#   0.4659999907016754,
#   0.420199990272522,
#   0.4616999924182892,
#   0.44040000438690186,
#   0.4729999899864197,
#   0.45329999923706055,
#   0.4496999979019165,
#   0.44600000977516174,
#   0.48179998993873596,
#   0.4672999978065491,
#   0.4724000096321106,
#   0.4537000060081482,
#   0.44940000772476196,
#   0.49570000171661377,
#   0.44940000772476196,
#   0.46810001134872437,
#   0.48249998688697815,
#   0.4893999993801117,
#   0.48590001463890076,
#   0.44749999046325684,
#   0.4724000096321106,
#   0.4715999960899353,
#   0.46560001373291016,
#   0.474700003862381,
#   0.47369998693466187,
#   0.47440001368522644,
#   0.4480000138282776,
#   0.4431999921798706,
#   0.45750001072883606,
#   0.4691999852657318,
#   0.4528000056743622,
#   0.43529999256134033,
#   0.4575999975204468,
#   0.43970000743865967,
#   0.46209999918937683,
#   0.4668000042438507,
#   0.4553000032901764,
#   0.46810001134872437,
#   0.46639999747276306,
#   0.4440999925136566,
#   0.45590001344680786],
#  'val_loss': [1.7667502164840698,
#   1.7129687070846558,
#   1.668517827987671,
#   1.664156436920166,
#   1.671554684638977,
#   1.5160552263259888,
#   1.6024587154388428,
#   1.6041678190231323,
#   1.5778169631958008,
#   1.5173407793045044,
#   1.7260769605636597,
#   1.5626360177993774,
#   1.7193619012832642,
#   1.5535151958465576,
#   1.6566890478134155,
#   1.6589211225509644,
#   1.7175968885421753,
#   1.5278944969177246,
#   1.5956592559814453,
#   1.5866855382919312,
#   1.5721389055252075,
#   1.6694560050964355,
#   1.5049078464508057,
#   1.684980034828186,
#   1.6113380193710327,
#   1.6016422510147095,
#   1.5303444862365723,
#   1.5638036727905273,
#   1.6697205305099487,
#   1.6475887298583984,
#   1.6478301286697388,
#   1.685394287109375,
#   1.6312161684036255,
#   1.6526377201080322,
#   1.6997030973434448,
#   1.7499446868896484,
#   1.8470804691314697,
#   1.744754433631897,
#   1.7406785488128662,
#   1.8443818092346191,
#   1.9195342063903809,
#   1.868140459060669,
#   1.9917757511138916,
#   1.791551947593689,
#   1.7758722305297852,
#   1.8698962926864624,
#   1.7569674253463745,
#   1.7889569997787476,
#   1.9041781425476074,
#   1.8065414428710938]}

# %%
fig,ax = plt.subplots(figsize=(12,5))
ax.plot(SL_model_history['loss'], label='sgd_loss',color='green')
ax.plot(SL_model_history['accuracy'], label='sgd_accuracy',color='green')
ax.plot(SL_model_history['val_loss'], label='sgd_val_loss',color='green',linestyle='--')
ax.plot(SL_model_history['val_accuracy'], label='sgd_val_accuracy',color='green',linestyle='--')

ax.plot(sgdm_model_history['loss'], label='sgdm_loss',color='yellow')
ax.plot(sgdm_model_history['accuracy'], label='sgdm_accuracy',color='yellow')
ax.plot(sgdm_model_history['val_loss'], label='sgdm_val_loss',color='yellow',linestyle='--')
ax.plot(sgdm_model_history['val_accuracy'], label='sgdm_val_accuracy',color='yellow',linestyle='--')

ax.plot(sgdmnv_model_history['loss'], label='sgdmnv_loss',color='orange')
ax.plot(sgdmnv_model_history['accuracy'], label='sgdmnv_accuracy',color='orange')
ax.plot(sgdmnv_model_history['val_loss'], label='sgdmnv_val_loss',color='orange',linestyle='--')
ax.plot(sgdmnv_model_history['val_accuracy'], label='sgdmnv_val_accuracy',color='orange',linestyle='--')

ax.plot(adam_model_history['loss'], label='adam_loss',color='red')
ax.plot(adam_model_history['accuracy'], label='adam_accuracy',color='red')
ax.plot(adam_model_history['val_loss'], label='adam_val_loss',color='red',linestyle='--')
ax.plot(adam_model_history['val_accuracy'], label='adam_val_accuracy',color='red',linestyle='--')

ax.plot(nadam_model_history['loss'], label='nadam_loss',color='blue')
ax.plot(nadam_model_history['accuracy'], label='nadam_accuracy',color='blue')
ax.plot(nadam_model_history['val_loss'], label='nadam_val_loss',color='blue', linestyle='--')
ax.plot(nadam_model_history['val_accuracy'], label='nadam_val_accuracy',color='blue', linestyle='--')

ax.plot(adagrad_model_history['loss'], label='adagrad_loss',color='purple')
ax.plot(adagrad_model_history['accuracy'], label='adagrad_accuracy',color='purple')
ax.plot(adagrad_model_history['val_loss'], label='adagrad_val_loss',color='purple', linestyle='--')
ax.plot(adagrad_model_history['val_accuracy'], label='adagrad_val_accuracy',color='purple', linestyle='--')

ax.legend(loc='upper left', bbox_to_anchor=(1, 1))

# %% [markdown]
# #regularizers:

# %%
model_l2_do = tf.keras.Sequential([
      #keras.layers.Dropout(rate=0.2),
      keras.layers.Dense(units =50,input_shape=(3072,),
                         kernel_initializer= keras.initializers.LecunNormal(seed=None),
                         kernel_regularizer=keras.regularizers.l2(l2=0.01)),
      keras.layers.Activation(activation='selu'),
      # keras.layers.Dropout(rate=0.2),
      #keras.layers.BatchNormalization(),
      keras.layers.Dense(units= 100, activation='selu', kernel_initializer= keras.initializers.LecunNormal(seed=None) ),
      keras.layers.Dropout(rate=0.2),
      keras.layers.BatchNormalization(),
      keras.layers.Dense(units= 10, activation='softmax')])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# compile model
opt = keras.optimizers.SGD(learning_rate=0.01,momentum=0.9,nesterov= True)
model_l2_do.compile(optimizer= 'adam', loss= 'categorical_crossentropy',metrics= ['accuracy'])

# %%
#  train model\
tf.data.experimental.enable_debug_mode()
checkpoint_path_regularize = "/content/drive/MyDrive/Folder_ch3_exe3/l2do_regularizer_modelchekpoint.keras"
callbacks = [keras.callbacks.ModelCheckpoint(checkpoint_path_regularize,  monitor='val_loss', verbose = 0, mode ='auto', save_freq = 'epoch',
                                             save_best_only = True )]
l2do_regularizer_model_history = model_l2_do.fit(X_train_n, y_train_ohe, epochs=100, validation_data= (X_val_n,y_val_ohe),callbacks=callbacks)
# Out:
# Epoch 1/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 104s 83ms/step - accuracy: 0.2743 - loss: 2.2315 - val_accuracy: 0.2490 - val_loss: 2.2771
# Epoch 2/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 105s 84ms/step - accuracy: 0.3263 - loss: 1.9700 - val_accuracy: 0.2789 - val_loss: 2.0731
# Epoch 3/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 103s 82ms/step - accuracy: 0.3385 - loss: 1.9411 - val_accuracy: 0.2913 - val_loss: 2.0346
# Epoch 4/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 102s 82ms/step - accuracy: 0.3445 - loss: 1.9190 - val_accuracy: 0.2870 - val_loss: 2.1186
# Epoch 5/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 101s 81ms/step - accuracy: 0.3506 - loss: 1.9113 - val_accuracy: 0.2556 - val_loss: 2.1083
# Epoch 6/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 105s 84ms/step - accuracy: 0.3573 - loss: 1.8890 - val_accuracy: 0.2806 - val_loss: 2.1098
# Epoch 7/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 111s 89ms/step - accuracy: 0.3571 - loss: 1.8731 - val_accuracy: 0.3409 - val_loss: 1.9563
# Epoch 8/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.3565 - loss: 1.8879 - val_accuracy: 0.3244 - val_loss: 1.9687
# Epoch 9/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 107s 86ms/step - accuracy: 0.3586 - loss: 1.8746 - val_accuracy: 0.3550 - val_loss: 1.8995
# Epoch 10/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 107s 86ms/step - accuracy: 0.3661 - loss: 1.8559 - val_accuracy: 0.3185 - val_loss: 2.0307
# Epoch 11/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 106s 85ms/step - accuracy: 0.3626 - loss: 1.8589 - val_accuracy: 0.3507 - val_loss: 1.8783
# Epoch 12/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 105s 84ms/step - accuracy: 0.3699 - loss: 1.8465 - val_accuracy: 0.3599 - val_loss: 1.8685
# Epoch 13/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 106s 85ms/step - accuracy: 0.3697 - loss: 1.8355 - val_accuracy: 0.3363 - val_loss: 1.9542
# Epoch 14/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 104s 83ms/step - accuracy: 0.3764 - loss: 1.8267 - val_accuracy: 0.3378 - val_loss: 1.9333
# Epoch 15/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 107s 85ms/step - accuracy: 0.3737 - loss: 1.8321 - val_accuracy: 0.3325 - val_loss: 1.9642
# Epoch 16/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 104s 83ms/step - accuracy: 0.3760 - loss: 1.8216 - val_accuracy: 0.3572 - val_loss: 1.9039
# Epoch 17/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 103s 83ms/step - accuracy: 0.3724 - loss: 1.8283 - val_accuracy: 0.2905 - val_loss: 2.0105
# Epoch 18/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 103s 82ms/step - accuracy: 0.3763 - loss: 1.8327 - val_accuracy: 0.3190 - val_loss: 1.9613
# Epoch 19/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 102s 82ms/step - accuracy: 0.3822 - loss: 1.8246 - val_accuracy: 0.3415 - val_loss: 1.9533
# Epoch 20/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 104s 83ms/step - accuracy: 0.3751 - loss: 1.8179 - val_accuracy: 0.2939 - val_loss: 2.2224
# Epoch 21/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 104s 83ms/step - accuracy: 0.3757 - loss: 1.8217 - val_accuracy: 0.3411 - val_loss: 1.9394
# Epoch 22/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 101s 81ms/step - accuracy: 0.3796 - loss: 1.8185 - val_accuracy: 0.3622 - val_loss: 1.8745
# Epoch 23/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 101s 81ms/step - accuracy: 0.3803 - loss: 1.8191 - val_accuracy: 0.3571 - val_loss: 1.8444
# Epoch 24/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 102s 82ms/step - accuracy: 0.3800 - loss: 1.8196 - val_accuracy: 0.3344 - val_loss: 1.9571
# Epoch 25/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 115s 92ms/step - accuracy: 0.3806 - loss: 1.8138 - val_accuracy: 0.3149 - val_loss: 1.9552
# Epoch 26/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 140s 112ms/step - accuracy: 0.3801 - loss: 1.8101 - val_accuracy: 0.3377 - val_loss: 1.9463
# Epoch 27/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 147s 118ms/step - accuracy: 0.3782 - loss: 1.8259 - val_accuracy: 0.3097 - val_loss: 2.1120
# Epoch 28/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 133s 106ms/step - accuracy: 0.3800 - loss: 1.8179 - val_accuracy: 0.3575 - val_loss: 1.8833
# Epoch 29/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 125s 100ms/step - accuracy: 0.3843 - loss: 1.8048 - val_accuracy: 0.3180 - val_loss: 1.9361
# Epoch 30/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 129s 103ms/step - accuracy: 0.3823 - loss: 1.8131 - val_accuracy: 0.2998 - val_loss: 2.1893
# Epoch 31/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 128s 103ms/step - accuracy: 0.3831 - loss: 1.8058 - val_accuracy: 0.3385 - val_loss: 1.9900
# Epoch 32/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 116s 93ms/step - accuracy: 0.3822 - loss: 1.8068 - val_accuracy: 0.3282 - val_loss: 1.9753
# Epoch 33/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 107s 85ms/step - accuracy: 0.3797 - loss: 1.8145 - val_accuracy: 0.3024 - val_loss: 2.1266
# Epoch 34/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 105s 84ms/step - accuracy: 0.3802 - loss: 1.8077 - val_accuracy: 0.3219 - val_loss: 2.0844
# Epoch 35/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 106s 85ms/step - accuracy: 0.3822 - loss: 1.8048 - val_accuracy: 0.3469 - val_loss: 1.9529
# Epoch 36/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 106s 85ms/step - accuracy: 0.3896 - loss: 1.7936 - val_accuracy: 0.3587 - val_loss: 1.8595
# Epoch 37/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 109s 87ms/step - accuracy: 0.3891 - loss: 1.7979 - val_accuracy: 0.3372 - val_loss: 1.9433
# Epoch 38/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 106s 85ms/step - accuracy: 0.3827 - loss: 1.8042 - val_accuracy: 0.3249 - val_loss: 2.0050
# Epoch 39/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 107s 86ms/step - accuracy: 0.3839 - loss: 1.7923 - val_accuracy: 0.3003 - val_loss: 2.0105
# Epoch 40/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 108s 87ms/step - accuracy: 0.3856 - loss: 1.7969 - val_accuracy: 0.3452 - val_loss: 1.9556
# Epoch 41/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 107s 85ms/step - accuracy: 0.3842 - loss: 1.8058 - val_accuracy: 0.3809 - val_loss: 1.8195
# Epoch 42/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.3857 - loss: 1.7953 - val_accuracy: 0.3679 - val_loss: 1.8377
# Epoch 43/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 111s 89ms/step - accuracy: 0.3843 - loss: 1.8056 - val_accuracy: 0.3582 - val_loss: 1.8972
# Epoch 44/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 107s 85ms/step - accuracy: 0.3890 - loss: 1.7966 - val_accuracy: 0.3582 - val_loss: 1.8656
# Epoch 45/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 105s 84ms/step - accuracy: 0.3820 - loss: 1.8025 - val_accuracy: 0.3187 - val_loss: 1.9770
# Epoch 46/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 106s 85ms/step - accuracy: 0.3874 - loss: 1.7944 - val_accuracy: 0.3829 - val_loss: 1.8135
# Epoch 47/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 136s 109ms/step - accuracy: 0.3861 - loss: 1.8057 - val_accuracy: 0.3474 - val_loss: 1.8917
# Epoch 48/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 105s 84ms/step - accuracy: 0.3851 - loss: 1.8011 - val_accuracy: 0.3058 - val_loss: 1.9894
# Epoch 49/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 103s 82ms/step - accuracy: 0.3823 - loss: 1.7927 - val_accuracy: 0.3725 - val_loss: 1.8080
# Epoch 50/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 106s 85ms/step - accuracy: 0.3893 - loss: 1.7924 - val_accuracy: 0.2542 - val_loss: 2.3416
# Epoch 51/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 108s 86ms/step - accuracy: 0.3893 - loss: 1.7989 - val_accuracy: 0.4029 - val_loss: 1.7456
# Epoch 52/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 112s 89ms/step - accuracy: 0.3836 - loss: 1.8034 - val_accuracy: 0.3165 - val_loss: 2.0876
# Epoch 53/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 107s 86ms/step - accuracy: 0.3912 - loss: 1.7844 - val_accuracy: 0.2573 - val_loss: 2.4688
# Epoch 54/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 122s 97ms/step - accuracy: 0.3789 - loss: 1.8040 - val_accuracy: 0.3395 - val_loss: 1.9805
# Epoch 55/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 119s 95ms/step - accuracy: 0.3860 - loss: 1.7935 - val_accuracy: 0.3816 - val_loss: 1.7991
# Epoch 56/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 111s 89ms/step - accuracy: 0.3863 - loss: 1.7953 - val_accuracy: 0.3706 - val_loss: 1.8598
# Epoch 57/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 108s 87ms/step - accuracy: 0.3902 - loss: 1.7944 - val_accuracy: 0.3125 - val_loss: 2.1235
# Epoch 58/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 104s 83ms/step - accuracy: 0.3846 - loss: 1.7963 - val_accuracy: 0.3863 - val_loss: 1.8247
# Epoch 59/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 112s 89ms/step - accuracy: 0.3843 - loss: 1.7902 - val_accuracy: 0.3584 - val_loss: 1.8599
# Epoch 60/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 116s 92ms/step - accuracy: 0.3878 - loss: 1.7941 - val_accuracy: 0.3366 - val_loss: 1.9061
# Epoch 61/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 118s 94ms/step - accuracy: 0.3854 - loss: 1.7855 - val_accuracy: 0.3298 - val_loss: 1.9683
# Epoch 62/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 117s 93ms/step - accuracy: 0.3849 - loss: 1.7993 - val_accuracy: 0.3934 - val_loss: 1.8087
# Epoch 63/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 119s 95ms/step - accuracy: 0.3837 - loss: 1.7929 - val_accuracy: 0.3461 - val_loss: 1.9102
# Epoch 64/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 117s 94ms/step - accuracy: 0.3840 - loss: 1.7947 - val_accuracy: 0.3827 - val_loss: 1.8143
# Epoch 65/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 118s 94ms/step - accuracy: 0.3959 - loss: 1.7770 - val_accuracy: 0.3589 - val_loss: 1.8448
# Epoch 66/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 117s 93ms/step - accuracy: 0.3873 - loss: 1.7948 - val_accuracy: 0.1967 - val_loss: 2.6815
# Epoch 67/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 108s 87ms/step - accuracy: 0.3903 - loss: 1.7841 - val_accuracy: 0.2479 - val_loss: 2.5046
# Epoch 68/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 109s 87ms/step - accuracy: 0.3890 - loss: 1.7849 - val_accuracy: 0.3520 - val_loss: 1.8767
# Epoch 69/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 108s 86ms/step - accuracy: 0.3888 - loss: 1.7850 - val_accuracy: 0.3513 - val_loss: 1.9352
# Epoch 70/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 109s 87ms/step - accuracy: 0.3856 - loss: 1.7938 - val_accuracy: 0.3109 - val_loss: 1.9602
# Epoch 71/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 108s 87ms/step - accuracy: 0.3960 - loss: 1.7755 - val_accuracy: 0.3759 - val_loss: 1.8373
# Epoch 72/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 114s 91ms/step - accuracy: 0.3892 - loss: 1.7872 - val_accuracy: 0.3069 - val_loss: 2.1065
# Epoch 73/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 118s 94ms/step - accuracy: 0.3907 - loss: 1.7813 - val_accuracy: 0.3933 - val_loss: 1.7787
# Epoch 74/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 116s 93ms/step - accuracy: 0.3927 - loss: 1.7885 - val_accuracy: 0.3482 - val_loss: 1.8813
# Epoch 75/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 115s 92ms/step - accuracy: 0.3857 - loss: 1.7975 - val_accuracy: 0.3387 - val_loss: 1.9747
# Epoch 76/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 114s 91ms/step - accuracy: 0.3973 - loss: 1.7740 - val_accuracy: 0.3306 - val_loss: 1.9203
# Epoch 77/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 114s 91ms/step - accuracy: 0.3864 - loss: 1.7859 - val_accuracy: 0.3465 - val_loss: 1.9168
# Epoch 78/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 108s 86ms/step - accuracy: 0.3887 - loss: 1.7893 - val_accuracy: 0.3745 - val_loss: 1.8255
# Epoch 79/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 108s 87ms/step - accuracy: 0.3850 - loss: 1.7934 - val_accuracy: 0.3572 - val_loss: 1.8744
# Epoch 80/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 108s 87ms/step - accuracy: 0.3830 - loss: 1.8009 - val_accuracy: 0.3628 - val_loss: 1.9071
# Epoch 81/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 109s 87ms/step - accuracy: 0.3861 - loss: 1.7932 - val_accuracy: 0.3809 - val_loss: 1.8041
# Epoch 82/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.3877 - loss: 1.7864 - val_accuracy: 0.3420 - val_loss: 1.9314
# Epoch 83/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 107s 86ms/step - accuracy: 0.3944 - loss: 1.7785 - val_accuracy: 0.3567 - val_loss: 1.8617
# Epoch 84/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 108s 86ms/step - accuracy: 0.3919 - loss: 1.7796 - val_accuracy: 0.3168 - val_loss: 2.0916
# Epoch 85/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 110s 88ms/step - accuracy: 0.3855 - loss: 1.7877 - val_accuracy: 0.3510 - val_loss: 1.8981
# Epoch 86/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 112s 90ms/step - accuracy: 0.3965 - loss: 1.7792 - val_accuracy: 0.3745 - val_loss: 1.7842
# Epoch 87/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 111s 89ms/step - accuracy: 0.3958 - loss: 1.7735 - val_accuracy: 0.3793 - val_loss: 1.7959
# Epoch 88/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 104s 83ms/step - accuracy: 0.3874 - loss: 1.7928 - val_accuracy: 0.3631 - val_loss: 1.8504
# Epoch 89/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 106s 85ms/step - accuracy: 0.3969 - loss: 1.7834 - val_accuracy: 0.3477 - val_loss: 1.9170
# Epoch 90/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 106s 85ms/step - accuracy: 0.3924 - loss: 1.7708 - val_accuracy: 0.3578 - val_loss: 1.8780
# Epoch 91/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 105s 84ms/step - accuracy: 0.3863 - loss: 1.7944 - val_accuracy: 0.3628 - val_loss: 1.8375
# Epoch 92/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 116s 93ms/step - accuracy: 0.3911 - loss: 1.7863 - val_accuracy: 0.3507 - val_loss: 1.9138
# Epoch 93/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 122s 98ms/step - accuracy: 0.3931 - loss: 1.7780 - val_accuracy: 0.3861 - val_loss: 1.7828
# Epoch 94/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 117s 94ms/step - accuracy: 0.3911 - loss: 1.7771 - val_accuracy: 0.3813 - val_loss: 1.8112
# Epoch 95/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 114s 91ms/step - accuracy: 0.3906 - loss: 1.7755 - val_accuracy: 0.3392 - val_loss: 1.9368
# Epoch 96/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 105s 84ms/step - accuracy: 0.3917 - loss: 1.7808 - val_accuracy: 0.3562 - val_loss: 1.8626
# Epoch 97/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 106s 85ms/step - accuracy: 0.3950 - loss: 1.7782 - val_accuracy: 0.3646 - val_loss: 1.8349
# Epoch 98/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 106s 85ms/step - accuracy: 0.3823 - loss: 1.7963 - val_accuracy: 0.3902 - val_loss: 1.7795
# Epoch 99/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 104s 83ms/step - accuracy: 0.3875 - loss: 1.7887 - val_accuracy: 0.3019 - val_loss: 2.1106
# Epoch 100/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 104s 83ms/step - accuracy: 0.3923 - loss: 1.7834 - val_accuracy: 0.3859 - val_loss: 1.7774

# %%
print('-------------training was finished------------')
# save  model & history
model_path= "/content/drive/My Drive/Folder_ch3_exe3/l2_do_regularizer_model.keras"
model_l2_do.save(model_path)

import pickle
#  path for save the pickle file
history_path_regularize = "/content/drive/My Drive/Folder_ch3_exe3/l2_do_regularizer_modelhistory.pkl"
# Save the dictionary as a pickle file
with open(history_path_regularize, 'wb') as pickle_file:
    pickle.dump(l2do_regularizer_model_history.history, pickle_file)

print('----------------regularize files were saved------------')
# Out:
# -------------training was finished------------
# ----------------regularize files were saved------------

# %%
import pickle
path ='/content/drive/MyDrive/Folder_ch3_exe3/l2_do_regularizer_modelhistory.pkl'
with open(path,mode='rb')as pickle_file:
  l2do_history= pickle.load(pickle_file)
path1 = '/content/drive/MyDrive/Folder_ch3_exe3/adam_model_history.pkl'
with open(path1,mode='rb')as pickle_file:
  No_reguliz_history= pickle.load(pickle_file)

# %%
fig,ax = plt.subplots(figsize=(12,5))
ax.plot( l2do_history['loss'], label='regulize_loss',color='green')
ax.plot( l2do_history['accuracy'], label='regulize_accuracy',color='green')
ax.plot( l2do_history['val_loss'], label='regulize_val_loss',color='green',linestyle='--')
ax.plot( l2do_history['val_accuracy'], label='regulize_val_accuracy',color='green',linestyle='--')

ax.plot(  No_reguliz_history['loss'], label='no_regulize_loss',color='red')
ax.plot(  No_reguliz_history['accuracy'], label='no_regulize_accuracy',color='red')
ax.plot(  No_reguliz_history['val_loss'], label='no_regulize_val_loss',color='red',linestyle='--')
ax.plot(  No_reguliz_history['val_accuracy'], label='no_regulize_val_accuracy',color='red',linestyle='--')

plt.title("loss and accuracy comparizon_ regulizer: l2 & dropout")
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))

# %%
# در نمودار خطوط قرمز اور فیت قبل از رگیولارایزیشن  کاملا مشخص است
# بعد از رگیولارایز کردن خطوط سبز اور فیت حذف شده اما دقت هم کمتر شده است

# %%
#  the model have overfit  befor regularization : accuracy of train is much bigger than validation and test sets.

unregulized_model = keras.models.load_model('/content/drive/MyDrive/Folder_ch3_exe3/adam_model.keras')
unregulized_model.load_weights('/content/drive/MyDrive/Folder_ch3_exe3/adam_modelchekpoint.keras')
unregulized_model.evaluate(X_train_n,y_train_ohe),unregulized_model.evaluate(X_val_n,y_val_ohe),unregulized_model.evaluate(X_test_n,y_test_ohe)
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/structured_function.py:258: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 23s 19ms/step - accuracy: 0.6155 - loss: 1.0657
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.5044 - loss: 1.4900
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.4859 - loss: 1.4953
# ([1.0651193857192993, 0.618399977684021],
#  [1.5049078464508057, 0.49570000171661377],
#  [1.5085899829864502, 0.48260000348091125])

# %%
#  the model don't have overfit  after regularization with l2 & Dropout but the accuracy  has decrized totaly

regulized_model = keras.models.load_model('/content/drive/MyDrive/Folder_ch3_exe3/l2_do_regularizer_model.keras')
regulized_model.load_weights('/content/drive/MyDrive/Folder_ch3_exe3/l2do_regularizer_modelchekpoint.keras')
regulized_model.evaluate(X_train_n,y_train_ohe),regulized_model.evaluate(X_val_n,y_val_ohe),regulized_model.evaluate(X_test_n,y_test_ohe)
# Out:
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 33s 26ms/step - accuracy: 0.4062 - loss: 1.7247
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 24ms/step - accuracy: 0.4075 - loss: 1.7393
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.4061 - loss: 1.7177
# ([1.7238261699676514, 0.40527498722076416],
#  [1.7456457614898682, 0.40290001034736633],
#  [1.7311029434204102, 0.39629998803138733])

# %% [markdown]
# ## monte carlo dropout

# %%
# y_test prediction
y_test_predict= np.round(regulized_model.predict(X_test_n),2)

# Make predictions with Monte Carlo Dropout  : reduce uncertainity in predictions
model_mcdo_predict= np.round(np.stack ([regulized_model(X_test_n,training= True) for _ in range (20)]),2)
mean_model_mcdo_predict = np.round(model_mcdo_predict.mean(axis=0),2)

model_mcdo_predict.shape, model_mcdo_predict.mean(axis=0).shape
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step
# ((20, 10000, 10), (10000, 10))

# %%
y_test_predict[1]    ,mean_model_mcdo_predict[1]     ,model_mcdo_predict[1]
# Out:
# (array([0.04, 0.4 , 0.  , 0.01, 0.  , 0.  , 0.  , 0.  , 0.17, 0.37],
#        dtype=float32),
#  array([0.04, 0.41, 0.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.2 , 0.34],
#        dtype=float32),
#  array([[0.05, 0.03, 0.12, ..., 0.01, 0.06, 0.01],
#         [0.04, 0.42, 0.  , ..., 0.01, 0.17, 0.34],
#         [0.06, 0.25, 0.  , ..., 0.  , 0.45, 0.22],
#         ...,
#         [0.02, 0.02, 0.05, ..., 0.15, 0.03, 0.03],
#         [0.03, 0.02, 0.09, ..., 0.05, 0.03, 0.01],
#         [0.04, 0.01, 0.14, ..., 0.28, 0.02, 0.03]], dtype=float32))

# %% [markdown]
# ### accuracy of Monte Carlo Dropout  test predictions:

# %%
# clarify the class of y
y_test_predict_do= np.argmax(y_test_predict, axis=1)
y_test_predict_mcdo = np.argmax(mean_model_mcdo_predict, axis=1)
real_classes = np.argmax(y_test_ohe, axis=1)
#predicted_classes.shape , real_classes.shape , y_test_predict_do.shape

# %%
# compare accuracy with and with out monte carlo Droout in test data

from sklearn.metrics import accuracy_score

accuracy_do = accuracy_score(real_classes, y_test_predict_do)
accuracy_mcdo = accuracy_score(real_classes, y_test_predict_mcdo )
print('model with dropout _test set evaluation  : ', accuracy_do  , end='\n'),
print('model with  Monte Carlo dropout _test set evaluation: ',accuracy_mcdo )
# Out:
# model with dropout _test set evaluation  :  0.4183
# model with  Monte Carlo dropout _test set evaluation:  0.4227
